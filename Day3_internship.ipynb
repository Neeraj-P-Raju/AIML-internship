# %% [markdown]
# <a href="https://colab.research.google.com/github/Neeraj-P-Raju/AIML-internship/blob/main/Day3_internship.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("/content/customer life time csv.csv")
df
# Out:
#             id  gender   area qualification         income  marital_status  \
# 0            1    Male  Urban      Bachelor         5L-10L               1
# 1            2    Male  Rural   High School         5L-10L               0
# 2            3    Male  Urban      Bachelor         5L-10L               1
# 3            4  Female  Rural   High School         5L-10L               0
# 4            5    Male  Urban   High School  More than 10L               1
# ...        ...     ...    ...           ...            ...             ...
# 148982  148983    Male  Rural      Bachelor         5L-10L               1
# 148983  148984    Male  Urban   High School         5L-10L               0
# 148984  148985  Female  Urban   High School          2L-5L               1
# 148985  148986    Male  Rural      Bachelor         5L-10L               0
# 148986  148987  Female  Urban      Bachelor         5L-10L               1
#
#         vintage  claim_amount num_policies policy type_of_policy      cltv
# 0             5          5790  More than 1      A       Platinum   64308.0
# 1             8          5080  More than 1      A       Platinum  515400.0
# 2             8          2599  More than 1      A       Platinum   64212.0
# 3             7             0  More than 1      A       Platinum   97920.0
# 4             6          3508  More than 1      A           Gold   59736.0
# ...         ...           ...          ...    ...            ...       ...
# 148982        6             0            1      A         Silver       NaN
# 148983        6             0            1      C           Gold       NaN
# 148984        4          3323  More than 1      B       Platinum       NaN
# 148985        1          2886  More than 1      A         Silver       NaN
# 148986        4          5939  More than 1      B       Platinum       NaN
#
# [148987 rows x 12 columns]

# %%
df.columns
# Out:
# Index(['id', 'gender', 'area', 'qualification', 'income', 'marital_status',
#        'vintage', 'claim_amount', 'num_policies', 'policy', 'type_of_policy',
#        'cltv'],
#       dtype='object')

# %%
df.describe()
# Out:
#                   id  marital_status        vintage   claim_amount  \
# count  148987.000000   148987.000000  148987.000000  148987.000000
# mean    74494.000000        0.576064       4.605523    4358.303201
# std     43008.986615        0.494182       2.287299    3272.692800
# min         1.000000        0.000000       0.000000       0.000000
# 25%     37247.500000        0.000000       3.000000    2402.000000
# 50%     74494.000000        1.000000       5.000000    4095.000000
# 75%    111740.500000        1.000000       6.000000    6098.000000
# max    148987.000000        1.000000       8.000000   32534.000000
#
#                 cltv
# count   89392.000000
# mean    97952.828978
# std     90613.814793
# min     24828.000000
# 25%     52836.000000
# 50%     66396.000000
# 75%    103440.000000
# max    724068.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148987 entries, 0 to 148986
# Data columns (total 12 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   id              148987 non-null  int64
#  1   gender          148987 non-null  object
#  2   area            148987 non-null  object
#  3   qualification   148987 non-null  object
#  4   income          148987 non-null  object
#  5   marital_status  148987 non-null  int64
#  6   vintage         148987 non-null  int64
#  7   claim_amount    148987 non-null  int64
#  8   num_policies    148987 non-null  object
#  9   policy          148987 non-null  object
#  10  type_of_policy  148987 non-null  object
#  11  cltv            89392 non-null   float64
# dtypes: float64(1), int64(4), object(7)
# memory usage: 13.6+ MB

# %%
df['cltv']
# Out:
# 0          64308.0
# 1         515400.0
# 2          64212.0
# 3          97920.0
# 4          59736.0
#             ...
# 148982         NaN
# 148983         NaN
# 148984         NaN
# 148985         NaN
# 148986         NaN
# Name: cltv, Length: 148987, dtype: float64

# %%
df[['id','gender','marital_status']]
# Out:
#             id  gender  marital_status
# 0            1    Male               1
# 1            2    Male               0
# 2            3    Male               1
# 3            4  Female               0
# 4            5    Male               1
# ...        ...     ...             ...
# 148982  148983    Male               1
# 148983  148984    Male               0
# 148984  148985  Female               1
# 148985  148986    Male               0
# 148986  148987  Female               1
#
# [148987 rows x 3 columns]

# %%
df.rename(columns={'id':'ID'},inplace=True)
df['ID']
# Out:
# 0              1
# 1              2
# 2              3
# 3              4
# 4              5
#            ...
# 148982    148983
# 148983    148984
# 148984    148985
# 148985    148986
# 148986    148987
# Name: ID, Length: 148987, dtype: int64

# %%
df.columns
# Out:
# Index(['ID', 'gender', 'area', 'qualification', 'income', 'marital_status',
#        'vintage', 'claim_amount', 'num_policies', 'policy', 'type_of_policy',
#        'cltv'],
#       dtype='object')

# %%
df.drop('cltv',axis=1,inplace=True)
df
# Out:
#             ID  gender   area qualification         income  marital_status  \
# 0            1    Male  Urban      Bachelor         5L-10L               1
# 1            2    Male  Rural   High School         5L-10L               0
# 2            3    Male  Urban      Bachelor         5L-10L               1
# 3            4  Female  Rural   High School         5L-10L               0
# 4            5    Male  Urban   High School  More than 10L               1
# ...        ...     ...    ...           ...            ...             ...
# 148982  148983    Male  Rural      Bachelor         5L-10L               1
# 148983  148984    Male  Urban   High School         5L-10L               0
# 148984  148985  Female  Urban   High School          2L-5L               1
# 148985  148986    Male  Rural      Bachelor         5L-10L               0
# 148986  148987  Female  Urban      Bachelor         5L-10L               1
#
#         vintage  claim_amount num_policies policy type_of_policy
# 0             5          5790  More than 1      A       Platinum
# 1             8          5080  More than 1      A       Platinum
# 2             8          2599  More than 1      A       Platinum
# 3             7             0  More than 1      A       Platinum
# 4             6          3508  More than 1      A           Gold
# ...         ...           ...          ...    ...            ...
# 148982        6             0            1      A         Silver
# 148983        6             0            1      C           Gold
# 148984        4          3323  More than 1      B       Platinum
# 148985        1          2886  More than 1      A         Silver
# 148986        4          5939  More than 1      B       Platinum
#
# [148987 rows x 11 columns]

# %%
wealth=df.groupby('ID')[['gender','area','qualification']].sum()
wealth
# Out:
#         gender   area qualification
# ID
# 1         Male  Urban      Bachelor
# 2         Male  Rural   High School
# 3         Male  Urban      Bachelor
# 4       Female  Rural   High School
# 5         Male  Urban   High School
# ...        ...    ...           ...
# 148983    Male  Rural      Bachelor
# 148984    Male  Urban   High School
# 148985  Female  Urban   High School
# 148986    Male  Rural      Bachelor
# 148987  Female  Urban      Bachelor
#
# [148987 rows x 3 columns]

# %%
claims=df.groupby('ID')['claim_amount'].sum()
claims
# Out:
# ID
# 1         5790
# 2         5080
# 3         2599
# 4            0
# 5         3508
#           ...
# 148983       0
# 148984       0
# 148985    3323
# 148986    2886
# 148987    5939
# Name: claim_amount, Length: 148987, dtype: int64

# %% [markdown]
# # Feature **Engineering**

# %%
import pandas as pd
fd=pd.read_csv("/content/titanic uncleaned.csv")
fd
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# 413                            Spector, Mr. Woolf    male   NaN      0      0
# 414                  Oliva y Ocana, Dona. Fermina  female  39.0      0      0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5      0      0
# 416                           Ware, Mr. Frederick    male   NaN      0      0
# 417                      Peter, Master. Michael J    male   NaN      1      1
#
#                  Ticket      Fare Cabin Embarked
# 0                330911    7.8292   NaN        Q
# 1                363272    7.0000   NaN        S
# 2                240276    9.6875   NaN        Q
# 3                315154    8.6625   NaN        S
# 4               3101298   12.2875   NaN        S
# ..                  ...       ...   ...      ...
# 413           A.5. 3236    8.0500   NaN        S
# 414            PC 17758  108.9000  C105        C
# 415  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416              359309    8.0500   NaN        S
# 417                2668   22.3583   NaN        C
#
# [418 rows x 12 columns]

# %%
fd.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# Pclass: This refers to the passenger class (1st, 2nd, or 3rd class). It's a proxy for socio-economic status, with 1st class being upper, 2nd middle, and 3rd lower class.
# SibSp: This indicates the number of siblings or spouses aboard the Titanic with the passenger. (Sibling = brother, sister, stepbrother, stepsister; Spouse = husband, wife (mistresses and fiancés were ignored)).
# Parch: This indicates the number of parents or children aboard the Titanic with the passenger. (Parent = mother, father; Child = daughter, son, stepdaughter, stepson. Some children travelled only with a nanny, therefore Parch=0 for them.)
# Embarked: This denotes the port of embarkation – where the passenger got on the ship. The typical codes are:
# 'C' = Cherbourg
# 'Q' = Queenstown
# 'S' = Southampton

# %%
fd.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 413        False     False   False  False  False   True  False  False   False
# 414        False     False   False  False  False  False  False  False   False
# 415        False     False   False  False  False  False  False  False   False
# 416        False     False   False  False  False   True  False  False   False
# 417        False     False   False  False  False   True  False  False   False
#
#       Fare  Cabin  Embarked
# 0    False   True     False
# 1    False   True     False
# 2    False   True     False
# 3    False   True     False
# 4    False   True     False
# ..     ...    ...       ...
# 413  False   True     False
# 414  False  False     False
# 415  False   True     False
# 416  False   True     False
# 417  False   True     False
#
# [418 rows x 12 columns]

# %%
fd.isnull().sum()

# %% [markdown]
# # **Missing value imputation**

# %%
fd['Age_mean_imputed'] = fd['Age'].fillna(fd['Age'].mean())
fd['Age_mean_imputed']
# Out:
# 0      34.50000
# 1      47.00000
# 2      62.00000
# 3      27.00000
# 4      22.00000
#          ...
# 413    30.27259
# 414    39.00000
# 415    38.50000
# 416    30.27259
# 417    30.27259
# Name: Age_mean_imputed, Length: 418, dtype: float64

# %%
fd['Age_median_imputed'] = fd['Age'].fillna(fd['Age'].median())
fd['Age_median_imputed']
# Out:
# 0      34.5
# 1      47.0
# 2      62.0
# 3      27.0
# 4      22.0
#        ...
# 413    27.0
# 414    39.0
# 415    38.5
# 416    27.0
# 417    27.0
# Name: Age_median_imputed, Length: 418, dtype: float64

# %%
fd['Cabin_mode_imputed'] = fd['Cabin'].fillna(fd['Cabin'].mode()[0])#counts from first index onwards and replace NuN  value by most repeated value/term
fd['Cabin_mode_imputed']
# Out:
# 0      B57 B59 B63 B66
# 1      B57 B59 B63 B66
# 2      B57 B59 B63 B66
# 3      B57 B59 B63 B66
# 4      B57 B59 B63 B66
#             ...
# 413    B57 B59 B63 B66
# 414               C105
# 415    B57 B59 B63 B66
# 416    B57 B59 B63 B66
# 417    B57 B59 B63 B66
# Name: Cabin_mode_imputed, Length: 418, dtype: object

# %%
fd[['Age','Age_mean_imputed','Age_median_imputed','Cabin','Cabin_mode_imputed']]
# Out:
#       Age  Age_mean_imputed  Age_median_imputed Cabin Cabin_mode_imputed
# 0    34.5          34.50000                34.5   NaN    B57 B59 B63 B66
# 1    47.0          47.00000                47.0   NaN    B57 B59 B63 B66
# 2    62.0          62.00000                62.0   NaN    B57 B59 B63 B66
# 3    27.0          27.00000                27.0   NaN    B57 B59 B63 B66
# 4    22.0          22.00000                22.0   NaN    B57 B59 B63 B66
# ..    ...               ...                 ...   ...                ...
# 413   NaN          30.27259                27.0   NaN    B57 B59 B63 B66
# 414  39.0          39.00000                39.0  C105               C105
# 415  38.5          38.50000                38.5   NaN    B57 B59 B63 B66
# 416   NaN          30.27259                27.0   NaN    B57 B59 B63 B66
# 417   NaN          30.27259                27.0   NaN    B57 B59 B63 B66
#
# [418 rows x 5 columns]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="whitegrid")

plt.figure(figsize=(10,6))
sns.boxplot(data=fd,x='Pclass',y='Age',palette='mako')

plt.title('Boxplot of Age by Pclass',fontsize=16)
plt.xlabel('Pclass',fontsize=12)
plt.ylabel('Age',fontsize=12)
plt.show()
# Out:
# /tmp/ipykernel_730/3676965188.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=fd,x='Pclass',y='Age',palette='mako')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="whitegrid")

plt.figure(figsize=(10,6))
sns.boxplot(data=fd,x='Embarked',y='Fare',palette='YlGnBu')

plt.title('Fair by Embarked',fontsize=16)
plt.xlabel('Embarked',fontsize=12)
plt.ylabel('Fare',fontsize=12)
plt.show()
# Out:
# /tmp/ipykernel_730/2108997221.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=fd,x='Embarked',y='Fare',palette='YlGnBu')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="whitegrid")

plt.figure(figsize=(10,6))
sns.boxplot(data=fd,x='Survived',y='Age',palette='plasma')

plt.title('Boxplot of Age by Survived',fontsize=16)
plt.xlabel('Survived',fontsize=12)
plt.ylabel('Age',fontsize=12)
plt.show()
# Out:
# /tmp/ipykernel_730/2478109107.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=fd,x='Survived',y='Age',palette='plasma')

# %%
numerical_features=fd.select_dtypes(include=['float64','int64'])
skewness=numerical_features.skew().sort_values(ascending=False)
print("Skewness of Numerical Features:")
print(skewness)
# Out:
# Skewness of Numerical Features:
# Parch          4.654462
# SibSp          4.168337
# Fare           3.687213
# Survived       0.568991
# Age            0.457361
# PassengerId    0.000000
# Pclass        -0.534170
# dtype: float64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15, 10))
for i, column in enumerate(numerical_features.columns, 1):
    plt.subplot((len(numerical_features.columns) // 3) + 1, 3, i)
    sns.histplot(fd[column].dropna(), kde=True, bins=30, color='blue')
    plt.title(f'{column} (Skewness: {skewness[column]:.2f})', fontsize=10)
    plt.xlabel(column, fontsize=8)
    plt.ylabel('Frequency', fontsize=8)

plt.tight_layout()
plt.show()

# %%
encoded_data = titanic_data.copy()
label_encoder= LabelEncoder()
encoded_data['Sex_Label'] = label_encoder.fit_transform(encoded_data['Sex'])
one_hot_encoded = pd.get_dummies(encoded_data['Embarked'], prefix='Embarked')
encoded_data = pd.concat([encoded_data, one_hot_encoded], axis=1)
pclass_mapping = {1: 'First', 2: 'Second', 3: 'Third'}
encoded_data['Pclass_Category'] = encoded_data['Pclass'].map(pclass_mapping)
print(encoded_data[['Sex', 'Sex_Label', 'Embarked', 'Embarked_Q', 'Embarked_S', 'Embarked_C', 'Pclass', 'Pclass_Category']].head())
# Out:
#       Sex  Sex_Label Embarked  Embarked_Q  Embarked_S  Embarked_C  Pclass  \
# 0    male          1        Q        True       False       False       3
# 1  female          0        S       False        True       False       3
# 2    male          1        Q        True       False       False       2
# 3    male          1        S       False        True       False       3
# 4  female          0        S       False        True       False       3
#
#   Pclass_Category
# 0           Third
# 1           Third
# 2          Second
# 3           Third
# 4           Third

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler
titanic_data = pd.read_csv('titanic uncleaned.csv')
titanic_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# 413                            Spector, Mr. Woolf    male   NaN      0      0
# 414                  Oliva y Ocana, Dona. Fermina  female  39.0      0      0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5      0      0
# 416                           Ware, Mr. Frederick    male   NaN      0      0
# 417                      Peter, Master. Michael J    male   NaN      1      1
#
#                  Ticket      Fare Cabin Embarked
# 0                330911    7.8292   NaN        Q
# 1                363272    7.0000   NaN        S
# 2                240276    9.6875   NaN        Q
# 3                315154    8.6625   NaN        S
# 4               3101298   12.2875   NaN        S
# ..                  ...       ...   ...      ...
# 413           A.5. 3236    8.0500   NaN        S
# 414            PC 17758  108.9000  C105        C
# 415  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416              359309    8.0500   NaN        S
# 417                2668   22.3583   NaN        C
#
# [418 rows x 12 columns]

# %%
numerical_columns=['Age','Fare','Pclass']
titanic_data.dropna(subset=numerical_columns,inplace=True)
minmax_scaler=MinMaxScaler()
standard_scaler=StandardScaler()
titanic_data['Age_MinMax'] = minmax_scaler.fit_transform(titanic_data[['Age']])
titanic_data['Fare_MinMax']=minmax_scaler.fit_transform(titanic_data[['Fare']])
titanic_data['Age_Standard']=standard_scaler.fit_transform(titanic_data[['Age']])
titanic_data['Fare_Standard']=standard_scaler.fit_transform(titanic_data[['Fare']])
titanic_data[['Age', 'Age_MinMax', 'Age_Standard']].head()
# Out:
#     Age  Age_MinMax  Age_Standard
# 0  34.5    0.452723      0.306657
# 1  47.0    0.617566      1.194236
# 2  62.0    0.815377      2.259331
# 3  27.0    0.353818     -0.225890
# 4  22.0    0.287881     -0.580922
